# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from collections import OrderedDict
import pickle
from minisom import MiniSom

# %%
vectorizedSentences = []
bestWordsFromSentences = []
allWordsFromSentences = []
allSentences = []
with open("data/vectorized_sentences", "rb") as fp:   # Unpickling
    vectorizedSentences = pickle.load(fp)
with open("data/best_words_for_sentences", "rb") as fp:   # Unpickling
    bestWordsFromSentences = pickle.load(fp)
with open("data/all_words_for_sentences", "rb") as fp:   # Unpickling
    allWordsFromSentences = pickle.load(fp)
with open("data/all_sentences", "rb") as fp:   # Unpickling
    allSentences = pickle.load(fp)
uniqueResultTuples = pd.read_csv("data/unique_result_tuples.csv")

# %%
uniqueResultTuples
# Out:
#   Unnamed: 0                                      prawo cywilne  \
# 0      words  [('spadku', 46), ('uchwały', 24), ('spadek', 2...
#
#                                prawo administracyjne  \
# 0  [('danych', 48), ('osobowych', 32), ('budowę',...
#
#                                 prawo farmaceutyczne  \
# 0  [('aptekę', 13), ('receptę', 12), ('zezwolenia...
#
#                                          prawo pracy  \
# 0  [('pracownika', 78), ('wypoczynkowego', 29), (...
#
#                                       prawo medyczne  \
# 0  [('specjalizacji', 52), ('dodatku', 46), ('cov...
#
#                                          prawo karne  \
# 0  [('przesłuchaniu', 23), ('przestępstwa', 9), (...
#
#                                 prawo miädzynarodowe  \
# 0  [('bezpieczeństwa', 3), ('granicami', 2), ('ar...
#
#                                      prawo podatkowe  \
# 0  [('kas', 5), ('fiskalną', 4), ('kasę', 3), ('f...
#
#                   prawo konstytucyjne
# 0  [('konstytucją', 2), ('wyjść', 2)]

# %%
def calculate_empty_lists(list: list):
    emptyLists = 0
    for l in list:
        if len(l) == 0:
            emptyLists+=1
    return emptyLists

# %% [markdown]
# VECTORIZED SENTENCES

# %%
tags = ['prawo cywilne','prawo administracyjne','prawo farmaceutyczne','prawo pracy','prawo medyczne','prawo międzynarodowe','prawo podatkowe','prawo konstytucyjne','prawo karne','inne']
colors = ['orange','red','blue','green','cyan','brown','black','purple','pink','#42458f']
def get_category_index(vector):
    index = 0
    value = 0
    for i, v in enumerate(vector):
        if v > value:
            value = v
            index = i
    return index

# %%
W = np.array(vectorizedSentences)

# %%
map_dim = 20
som = MiniSom(map_dim, map_dim, 10, sigma=1.0, random_seed=1)
# som.random_weights_init(W)
som.train_batch(W, num_iteration=len(W)*500, verbose=True)
# Out:
#  [ 267200 / 267200 ] 100% - 0:00:00 left
#  quantization error: 0.0030924780221774327

# %%
def get_best_word_from_list(affair: str,words: list):
    if affair == 'prawo międzynarodowe':
        affair = 'prawo miädzynarodowe'
    b = eval(uniqueResultTuples[affair][0])
    value = 0
    result = ''
    for word in words:
        for tuple in b:
            if tuple[0] == word and tuple[1] > value:
                value = tuple[1]
                result = word
    if len(words) > 0 and result == '':
        result = words[0]
    return result

# %%
def change_best_words_to_best_word():
    result = []
    for i,list in enumerate(bestWordsFromSentences):
        categoryIndex = get_category_index(vectorizedSentences[i])
        category = tags[categoryIndex]
        if len(list) == 1:
            result.extend(list)
        else:
            result.append(get_best_word_from_list(category,list))
    return result
bestWordsFromSentences = change_best_words_to_best_word()

# %%
bestWordsFromSentences
# Out:
# ['lokali',
#  'pomieszczenie',
#  '',
#  'niepełnosprawnych',
#  'uchwałą',
#  'uchwały',
#  'jaką',
#  'skład',
#  'uchwały',
#  'uchwały',
#  'lokali',
#  'ogrzewania',
#  'lokali',
#  '',
#  'wybudować',
#  'uchwały',
#  'uchwały',
#  '',
#  'właścicielka',
#  'parkingowym',
#  'naprawy',
#  'starego',
#  'uchwały',
#  'zarządca',
#  'bankowych',
#  'osobowe',
#  'głosów',
#  'kosztach',
#  'wymienić',
#  'roszczenie',
#  'wartość',
#  'budowlanego',
#  'salonu',
#  'wieczystej',
#  'utraconego',
#  '',
#  'podejrzeniem',
#  'stażysta',
#  'będzie',
#  'zawodowego',
#  'dziedziczenia',
#  'zatrudniona',
#  'zaległe',
#  'pani',
#  '',
#  '',
#  'skład',
#  'drodze',
#  '',
#  'pracować',
#  '',
#  '',
#  'przyjęcia',
#  'farmacji',
#  'drugą',
#  'własną',
#  'winna',
#  'własną',
#  '',
#  'lekarza',
#  'charakterze',
#  '',
#  'zakazu',
#  'szpitalem',
#  'podpisanie',
#  '',
#  'oblicza',
#  'właścicielu',
#  'pracować',
#  'zadań',
#  'karnym',
#  'skrócenia',
#  'równoważnym',
#  '',
#  'dokumentację',
#  '',
#  'tomografii',
#  'zezwolenia',
#  'ochrona',
#  'szpitalnej',
#  'kategorii',
#  'przestępstwa',
#  'innych',
#  'doprowadzić',
#  'dojazdowej',
#  '',
#  'wziąć',
#  'przestępstwa',
#  'kategorii',
#  'nabywcą',
#  'bankowych',
#  'poszczególnych',
#  'wody',
#  'nabywcą',
#  'ubezwłasnowolniona',
#  'zakładowego',
#  'szpitalnej',
#  'zmiana',
#  'zwolnioną',
#  'podmiocie',
#  'obniżyć',
#  'pobierającego',
#  'możliwe',
#  '',
#  'zmusić',
#  '',
#  'szkolenie',
#  'charakterze',
#  'zezwolenia',
#  'recepcie',
#  'opiekuna',
#  'przyjęcia',
#  '',
#  '',
#  '',
#  'komornik',
#  'ograniczyć',
#  'uchwały',
#  '',
#  'jakie',
#  'zabiegu',
#  'jednostronne',
#  '',
#  'ośrodka',
#  'fiskalną',
#  'minimalnego',
#  '',
#  'nadliczbowych',
#  '',
#  '',
#  '',
#  '',
#  'niepełnosprawności',
#  'zachowku',
#  'komentarz',
#  'skład',
#  'jakie',
#  'możliwy',
#  'karnego',
#  'powiększenie',
#  'dyżurować',
#  'klientowi',
#  'dodatkowego',
#  '',
#  'przyjęcia',
#  'wypowiedziana',
#  '',
#  'prawne',
#  'przyjęcia',
#  'jakie',
#  'dyskryminację',
#  'posiadania',
#  'psycholog',
#  '',
#  'instytucja',
#  'udostępnienia',
#  '',
#  'uznane',
#  'właścicielu',
#  'niedziele',
#  'udzielenie',
#  'utrzymania',
#  'odprawa',
#  'dyżurze',
#  '',
#  'prawna',
#  'odpowiedniej',
#  'dodatkowego',
#  'specjalizacyjnego',
#  'ograniczoną',
#  'odpowiedniej',
#  'aptekę',
#  'odpowiedniej',
#  'udzielania',
#  'kontakt',
#  'obecną',
#  'osobą',
#  'sarscov',
#  'planu',
#  'epidemiologicznego',
#  'pracownikowi',
#  'wypoczynkowego',
#  '',
#  '',
#  'wypoczynkowego',
#  'wynikającej',
#  'zwolniony',
#  'wyciekiem',
#  'prowizji',
#  'skierowaniu',
#  'bezpłatny',
#  'skierowanie',
#  'prowizji',
#  'pracownikowi',
#  'kontynuować',
#  'lekarzom',
#  'dziedziczenia',
#  'podstawy',
#  'wypoczynkowego',
#  'urlopów',
#  'obecną',
#  'ochronnych',
#  '',
#  '',
#  'biura',
#  'farmaceutyczne',
#  '',
#  '',
#  'wyjść',
#  'sądowej',
#  'będzie',
#  'jakie',
#  'prezes',
#  'podmiot',
#  'zakaźnym',
#  'koronawirusa',
#  'jednym',
#  'pielęgniarek',
#  'ogólnodostępna',
#  '',
#  'stażu',
#  '',
#  'limit',
#  'uchylenie',
#  'niewykorzystany',
#  '',
#  'dziedziczenia',
#  '',
#  'obecną',
#  'skład',
#  'świadczenie',
#  'pojechać',
#  '',
#  'stanu',
#  'oddział',
#  'informowania',
#  'skutek',
#  'pacjentce',
#  'skuteczność',
#  'tarczy',
#  '',
#  'pracownikowi',
#  'jakie',
#  'ochronnych',
#  'opieką',
#  'lekarzem',
#  'miejscach',
#  '',
#  'karnego',
#  '',
#  'świadczenie',
#  'bezpłatny',
#  'zostać',
#  '',
#  'wojewoda',
#  'wojewody',
#  'kwarantannie',
#  'ochronnych',
#  'wysłać',
#  'kontynuować',
#  'kwarantannę',
#  'zaległych',
#  'wojewody',
#  'opłacania',
#  'warunków',
#  'opłacania',
#  'lekarzom',
#  'szczególnych',
#  '',
#  '',
#  'wypoczynkowego',
#  '',
#  'stanu',
#  'program',
#  '',
#  'napisać',
#  'skierowanie',
#  'koronawirusa',
#  'wypełnia',
#  'pracownikowi',
#  'zaświadczenie',
#  'przestoju',
#  'zwalczaniu',
#  'stopnia',
#  'zgodzić',
#  'certyfikat',
#  '',
#  '',
#  'pojechać',
#  'godzinną',
#  'wojewody',
#  'stażysta',
#  'prowizji',
#  'urlopów',
#  '',
#  'sanepid',
#  '',
#  'ograniczeń',
#  '',
#  'wykonanie',
#  'oddziałach',
#  'stażysta',
#  'pracownicy',
#  'stażysta',
#  'wydłuża',
#  'narodowym',
#  'urlopów',
#  'programu',
#  'osoba',
#  'pracach',
#  'dyżur',
#  'opłacania',
#  'programu',
#  '',
#  'tarczy',
#  'porozumienie',
#  '',
#  'wojewody',
#  '',
#  'maseczek',
#  'budowy',
#  '',
#  'dostarczyć',
#  'wprowadzić',
#  'wiadomości',
#  'programu',
#  '',
#  'być',
#  'dostarczenia',
#  'znieczulenia',
#  'dostarczyć',
#  'kontaktu',
#  '',
#  'przyjmować',
#  'udziela',
#  'konflikt',
#  'kwarantanną',
#  'zapobieganiu',
#  'postąpić',
#  'wymiaru',
#  'jednostki',
#  'wypłacać',
#  'wskazanej',
#  'stażysta',
#  'miejscach',
#  'jaką',
#  'przeznaczyć',
#  'dofinansowanie',
#  'zewnątrz',
#  'parlamentu',
#  'zostać',
#  'świadczenie',
#  '',
#  '',
#  'obniżyć',
#  'kierownik',
#  '',
#  'lekarzem',
#  'zapewnienie',
#  'sąd',
#  'spełnia',
#  'cofnąć',
#  'posłać',
#  'konflikt',
#  'utraconego',
#  'zasadniczego',
#  '',
#  '',
#  'pracownicy',
#  '',
#  'przetwarzaniem',
#  'spadkową',
#  '',
#  '',
#  'pracownikom',
#  'zgonu',
#  'grudnia',
#  'sądzie',
#  'własność',
#  '',
#  'przyznanie',
#  'przedłużony',
#  'skierowany',
#  'ubiegania',
#  'będąca',
#  'jakie',
#  'wynajmujący',
#  'przebywać',
#  'poradni',
#  'pracownikowi',
#  'ponosić',
#  'wojewody',
#  'urlopów',
#  'wprowadzenie',
#  '',
#  'ankiety',
#  'podatkowa',
#  'dodatkowych',
#  '',
#  'zamknąć',
#  'udostępnienia',
#  'podejrzenie',
#  'lekarzem',
#  '',
#  'dokumentacja',
#  'dyżur',
#  'budowę',
#  'sanitarnego',
#  'urlopu',
#  'internecie',
#  '',
#  'ochronnych',
#  '',
#  '',
#  'przesłanki',
#  'przedłużony',
#  'zezwolenia',
#  'zaświadczenie',
#  'krewnej',
#  'prowadząca',
#  'zakażeniem',
#  'wyjątki',
#  'wspólnej',
#  'jakie',
#  'sądowych',
#  'służebności',
#  '',
#  'propozycje',
#  'epidemią',
#  'wypoczynkowego',
#  'skrócić',
#  'wyniku',
#  'urlopów',
#  'powołać',
#  '',
#  'zaprzestania',
#  'dyżurowania',
#  'będzie',
#  'okresowe',
#  'maszynistów',
#  'zasiedzenia',
#  'wezwaniem',
#  '',
#  'porozumieniem',
#  '',
#  'powołać',
#  'ankiety',
#  'zestawienia',
#  'związku',
#  'zapotrzebowanie',
#  'salonie',
#  'podpisanie',
#  'rozmowę',
#  'zaliczki',
#  'wezwaniem',
#  'datą',
#  'opłacania',
#  'przesłuchania',
#  'wezwać',
#  '',
#  'dóbr',
#  'apteka',
#  '',
#  'przebywając',
#  'ceny',
#  'gminie',
#  'refundacja',
#  'pobierać',
#  'spadkowe',
#  'ciągu',
#  'wpływają',
#  'osobowe',
#  'pacjentowi',
#  'odurzające',
#  'konto',
#  'wolności',
#  '',
#  'podmiotem',
#  'szkoleniowego',
#  '',
#  'wymiaru',
#  'teściowa',
#  '',
#  '',
#  'dokumentacja',
#  'kreują',
#  'drugą',
#  'pracować',
#  'stawiennictwo',
#  'muszą',
#  'potrzebuje',
#  'obejmować',
#  'stosować',
#  '',
#  '',
#  '',
#  'zarząd',
#  '',
#  'warunków',
#  'recepcie',
#  'pracownikowi',
#  '',
#  'szkolenie',
#  'pracownicy',
#  'wezwaniem',
#  'walki',
#  'wezwaniem',
#  'szpitalem',
#  'wniesienie',
#  'zapłacić',
#  'pielęgniarek',
#  'podlegają',
#  '',
#  'zaległego',
#  'dokonanie',
#  'uchwały',
#  'uchwały',
#  'jakie',
#  'epidemiologiczną',
#  'nowy',
#  '',
#  'właściciela',
#  'współwłasności',
#  '',
#  'całą',
#  'zarząd',
#  'wprowadzić',
#  'podpisaniu',
#  '',
#  'zakończyć',
#  'prace',
#  'wątpliwości',
#  'testy',
#  'suplementy',
#  'nieobecność',
#  'żądanej',
#  'ubezpieczycielowi',
#  'udziałów',
#  'rzecznik',
#  'podziału',
#  'nałożenia',
#  'jakie',
#  'majątkiem',
#  'pracownikowi',
#  'przewidzianym',
#  'jakie',
#  'porządkowej',
#  'stosunek',
#  'usunięcia',
#  '',
#  'niewykorzystany',
#  'zachowek',
#  'darowizny',
#  '',
#  'liczyć',
#  '',
#  'dziedziczenia',
#  'długów',
#  'numeru',
#  'niezgodne',
#  'funkcjonuje',
#  'piśmie',
#  '',
#  'karnym',
#  'funkcję',
#  '',
#  '',
#  'zmian',
#  'muszą',
#  '',
#  '',
#  '',
#  'sama',
#  'zdjęcia',
#  'skierować',
#  '',
#  'sprzedawcy',
#  'porozumieniem',
#  '',
#  'wartość',
#  'szczepienie',
#  'dokumentacją',
#  '',
#  'odmawia',
#  'skład',
#  'przekształcić',
#  '',
#  '',
#  'konieczny',
#  'ministra',
#  'stawiennictwa',
#  'specjalizacyjnego',
#  'odbierania',
#  'czas',
#  '',
#  'odbywać',
#  'domowych',
#  'właścicielka',
#  'składania',
#  '',
#  'lecznicze',
#  'jakie',
#  'osobowe',
#  'kontraktu',
#  'dane',
#  'usunięcia',
#  'ponoszenia',
#  'wymaganych',
#  'ogrodzenie',
#  'refundacji',
#  'aptek',
#  '',
#  '',
#  'zatrudnionym',
#  'najemca',
#  'prawna',
#  'fakturę',
#  'rozliczać',
#  'pracach',
#  'kwot',
#  'przyjmowania',
#  'farmacji',
#  'zamontować',
#  'żołnierz',
#  'uchwały',
#  'odbyciu',
#  '',
#  'spłaty',
#  'zapotrzebowanie',
#  'kierownik',
#  'zawiesić',
#  '',
#  'oddawać',
#  'podpisanie',
#  'likwidacji',
#  'udostępnianie',
#  'organ',
#  'oblicza',
#  'faktyczny',
#  'przesłuchania',
#  'uda',
#  'rodzicielskim',
#  '',
#  'udziałów',
#  '',
#  'zakupiony',
#  'dotyczącego',
#  'receptę',
#  'skład',
#  'polisę',
#  'środki',
#  'nałożenia',
#  'wprowadzenie',
#  '',
#  '',
#  'przysługującego',
#  'zaistniałych',
#  'budowlane',
#  '',
#  'wykonania',
#  'bezobjawowy',
#  'jakie',
#  'elementy',
#  'punktu',
#  'specjalizacyjnego',
#  'jakie',
#  'niezgodne',
#  'podawać',
#  'farmaceutyczne',
#  '',
#  'komunikat',
#  'leczniczej',
#  'mandatem',
#  '',
#  'umorzenie',
#  'testament',
#  '',
#  'przyjść',
#  'liczyć',
#  'odprawa',
#  'koronawirusa',
#  'prac',
#  'wypoczynkowego',
#  '',
#  'stawienia',
#  'dyżuru',
#  'zarządowi',
#  'skarg',
#  'specjalizacyjnego',
#  'fakturze',
#  'określają',
#  'reguluje',
#  '',
#  'skierowanie',
#  'pacjentami',
#  'refundację',
#  'wizytę',
#  'zapisać',
#  'inny',
#  'zakładowego',
#  'specjalizacje',
#  'sprawozdanie',
#  'zdalną',
#  'przedłużyć',
#  'dojazdowej',
#  'niepełnosprawności',
#  'zakładowego',
#  '',
#  'zapisać',
#  'karmienie',
#  'seniora',
#  'nosa',
#  'skierowany',
#  'szkolenie',
#  'czas',
#  'księgi',
#  '',
#  'klauzuli',
#  'sanitarnego',
#  'dyżur',
#  'zapobieganiu',
#  'szkolenie',
#  'wysokości',
#  'wprowadzenie',
#  'roszczeniami',
#  'pracownikowi',
#  'własności',
#  '',
#  'stanu',
#  'zaniedbanie',
#  'znajdujące',
#  'dodatkowy',
#  '',
#  'wizyty',
#  'raz',
#  'osobowe',
#  'roszczenie',
#  '',
#  'odmówi',
#  '',
#  'pełnić',
#  'zmianę',
#  '',
#  'decyzją',
#  'decyzją',
#  'niepełnym',
#  'datę',
#  'program',
#  'klientowi',
#  'domowych',
#  '',
#  'życia',
#  'instytucja',
#  'wypoczynkowego',
#  'nosa',
#  'podziału',
#  'przesłuchania',
#  '',
#  'eksmisji',
#  'zgonu',
#  'wymiaru',
#  'stażysta',
#  'zarządca',
#  'pracować',
#  'majątkiem',
#  '',
#  'odbycia',
#  'współwłasności',
#  'pisemnej',
#  'użytkowego',
#  'domowych',
#  'samodzielnego',
#  '',
#  'zaistniałych',
#  'ubezwłasnowolniona',
#  'darowizny',
#  'wojewoda',
#  'skierowany',
#  'spłaty',
#  'pełnomocnictwo',
#  'umiejętnościami',
#  'zaistniałych',
#  '',
#  'wychowawczym',
#  'zainstalowania',
#  '',
#  'złożone',
#  '',
#  'stażysta',
#  'narusza',
#  'zatrudniać',
#  'towarzyszące',
#  '',
#  'niewykorzystane',
#  'zmianę',
#  'wykonania',
#  '',
#  'muszą',
#  '',
#  'odbywa',
#  'reklamację',
#  'ochronie',
#  'porozumieniem',
#  'wychowawczym',
#  'uchwałę',
#  'zdalną',
#  'rozliczenie',
#  'ubezpieczycielowi',
#  'spłaty',
#  'odbycia',
#  '',
#  'odrzucić',
#  'stażu',
#  'wychowuje',
#  'ceny',
#  'klauzuli',
#  'praktyką',
#  'pacjentowi',
#  'jakie',
#  'skierowany',
#  'otrzymanym',
#  'familiae',
#  'związany',
#  'pełnić',
#  'covidowy',
#  'lekarzom',
#  'kolejne',
#  'zapobieganiu',
#  '',
#  '',
#  '',
#  'odmowę',
#  'choroby',
#  'pracować',
#  'dyżurze',
#  'wykonanie',
#  'aptek',
#  'pacjentowi',
#  'salonu',
#  'uchwały',
#  'elewacji',
#  'konserwatora',
#  'salon',
#  'elewacji',
#  'wykonanie',
#  'salonu',
#  'pisemne',
#  'jednoosobowej',
#  'stawkę',
#  'pozwolenia',
#  'budowy',
#  'remontu',
#  '',
#  'muszą',
#  'opinie',
#  'seniorów',
#  'chorych',
#  '',
#  '',
#  'szkodę',
#  'służbowe',
#  'okolicznościach',
#  'emeryturze',
#  'prywatnym',
#  'pozew',
#  'spadkowe',
#  '',
#  'wykonywaniu',
#  '',
#  'kwarantanny',
#  'zasiedzenie',
#  'listę',
#  'formy',
#  'stycznia',
#  '',
#  'wezwana',
#  '',
#  'recepcie',
#  'kierownicze',
#  'kwalifikacyjne',
#  '',
#  'uzasadnić',
#  'skutkować',
#  '',
#  'dokumentacja',
#  'wypłaty',
#  'pozwolenia',
#  'stażysta',
#  'porozumieniem',
#  'zaistniałych',
#  'zweryfikować',
#  'refundacji',
#  '',
#  '',
#  'spadkową',
#  'ponosi',
#  'covidowego',
#  'szkolenie',
#  'muszą',
#  'oddelegowaniem',
#  'wypoczynkowego',
#  'pracownikom',
#  'odpowiedzialną',
#  'substancji',
#  'skład',
#  '',
#  'zakażonych',
#  'zawnioskować',
#  'całości',
#  'prywatny',
#  'lekarzem',
#  'kwalifikować',
#  'covidowy',
#  'obecną',
#  'określił',
#  'współwłaścicielami',
#  'swobodnego',
#  'odbywanie',
#  'stawiennictwa',
#  'doręczone',
#  'skład',
#  'szczepienie',
#  'kontynuować',
#  'przeprowadzenie',
#  'współpracuje',
#  'zapisać',
#  '',
#  '',
#  'samochody',
#  '',
#  'szczepienie',
#  'leczniczej',
#  '',
#  'familiae',
#  'wzywać',
#  'pacjentami',
#  'kwalifikowanie',
#  'akcji',
#  'świadków',
#  'usunięcia',
#  'własności',
#  'placówkami',
#  'prowizji',
#  'hipoteki',
#  'spadkobiercy',
#  'dziedziny',
#  '',
#  'lekarza',
#  'utraconego',
#  '',
#  'sytuacją',
#  '',
#  '',
#  'wszcząć',
#  '',
#  'refundowane',
#  'parkingowym',
#  'szkolenie',
#  'budowę',
#  'chorych',
#  'spadkobierców',
#  'chorych',
#  'powiększenie',
#  'powrocie',
#  '',
#  'zakupiony',
#  'podstawie',
#  'testamentu',
#  'własności',
#  'odpowiedzialności',
#  'gospodarstwo',
#  'podać',
#  'spadkobierców',
#  'obowiązują',
#  'podział',
#  'stażysta',
#  'asystentki',
#  'prawna',
#  'zbierania',
#  '',
#  'przyjąć',
#  'opinie',
#  'odbywanie',
#  'uczynić',
#  'budowę',
#  'uczynić',
#  'wieczystej',
#  'przekazać',
#  'rezydentury',
#  'podyplomowy',
#  'składania',
#  'budowę',
#  'punktu',
#  'modelowanie',
#  'spadkobiercą',
#  'będący',
#  'zezwolenia',
#  'podmiocie',
#  'zasadne',
#  '',
#  ...]

# %%
def remove_elements_from_list_by_indexes(list: list, indexes: list):
    result = []
    for i,l in enumerate(list):
        if i not in indexes:
            result.append(l)
    return result

# %%
def get_indexes_of_repeated_words():
    toRemove = []
    for i,word in enumerate(bestWordsFromSentences):
        for i2, word2, in enumerate(bestWordsFromSentences):
            if word != 'none' and i != i2 and i2 > i and word == word2:
                toRemove.append(i2)
    return toRemove

indexesToRemove = get_indexes_of_repeated_words()
indexesToRemove = [*set(indexesToRemove)]
print('Got {} repeated words to delete from {}'.format(len(indexesToRemove),len(bestWordsFromSentences)))
bestWords = remove_elements_from_list_by_indexes(bestWordsFromSentences,indexesToRemove)
vectors =  remove_elements_from_list_by_indexes(vectorizedSentences,indexesToRemove)
allWords = remove_elements_from_list_by_indexes(allWordsFromSentences,indexesToRemove)
allSentences = remove_elements_from_list_by_indexes(allSentences,indexesToRemove)
# Out:
# Got 1607 repeated words to delete from 2672

# %%
def get_indexes_of_empty_words(list):
    toRemove = []
    for i,word in enumerate(list):
        if word == '':
            toRemove.append(i)
    return toRemove
indexesToRemove = get_indexes_of_empty_words(bestWords)
print('Got {} empty words to delete from {}'.format(len(indexesToRemove),len(bestWords)))
bestWords = remove_elements_from_list_by_indexes(bestWords,indexesToRemove)
vectors =  remove_elements_from_list_by_indexes(vectors,indexesToRemove)
allWords = remove_elements_from_list_by_indexes(allWords,indexesToRemove)
allSentences = remove_elements_from_list_by_indexes(allSentences,indexesToRemove)
# Out:
# Got 1 empty words to delete from 1065

# %%
print('bestWords({}) == vectors({}) == allWords({})'.format(len(bestWords),len(vectors),len(allWords)))
# Out:
# bestWords(1064) == vectors(1064) == allWords(1064)

# %%
numberOfDocumentsInCategory = [0]*10

def reset_number_of_documents_in_category():
    for index,num in enumerate(numberOfDocumentsInCategory):
        numberOfDocumentsInCategory[index] =0

def update_number_of_documents_in_category(index: int):
    numberOfDocumentsInCategory[index] += 1

def print_number_of_documents_in_category():
    for index, category in enumerate(tags):
        print('{}: {}'.format(category,numberOfDocumentsInCategory[index]))

# %%
print(str(len(vectorizedSentences)))
print(str(len(vectors)))
# Out:
# 2672
# 1064

# %%
import ast
from matplotlib.patches import Patch
legend_elements = []
for index,color in enumerate(colors):
    c = colors[index]
    l = tags[index]
    legend_elements.append(Patch(facecolor=c, edgecolor='black',label=l))
plt.figure(figsize=(20, 20))
texts = []
reset_number_of_documents_in_category()
for i,vec in enumerate(vectorizedSentences):
    affairIndex = get_category_index(vec)
    update_number_of_documents_in_category(affairIndex)
    c = colors[affairIndex]
    winnin_position = som.winner(vec)
    text = ''
    if len(bestWordsFromSentences[i]) > 0:
        text = bestWordsFromSentences[i]
    if text != "":
        texts.append(plt.text((winnin_position[0]+np.random.rand()*.9)%map_dim, (winnin_position[1]+np.random.rand()*.9)%map_dim, '⚫', color=c))

print_number_of_documents_in_category()

plt.legend(handles=legend_elements, loc='upper left',prop={'size': 15})
# plt.xticks(range(map_dim))
# plt.yticks(range(map_dim))
# plt.grid()
plt.xlim([0, map_dim])
plt.ylim([0, map_dim])
plt.plot()
# Out:
# prawo cywilne: 888
# prawo administracyjne: 156
# prawo farmaceutyczne: 210
# prawo pracy: 319
# prawo medyczne: 839
# prawo międzynarodowe: 6
# prawo podatkowe: 61
# prawo konstytucyjne: 2
# prawo karne: 191
# inne: 0
# []

# %%
import ast
from matplotlib.patches import Patch
legend_elements = []
for index,color in enumerate(colors):
    c = colors[index]
    l = tags[index]
    legend_elements.append(Patch(facecolor=c, edgecolor='black',label=l))
plt.figure(figsize=(20, 20))
texts = []
reset_number_of_documents_in_category()
for i,vec in enumerate(vectors):
    affairIndex = get_category_index(vec)
    update_number_of_documents_in_category(affairIndex)
    c = colors[affairIndex]
    winnin_position = som.winner(vec)

    # for bestWord in bestWordsFromSentences[i]:
    #     if bestWord != "":
    #         texts.append(plt.text((winnin_position[0]+np.random.rand()*.9)%map_dim, (winnin_position[1]+np.random.rand()*.9)%map_dim, bestWord, color=c))

    text = bestWords[i]
    if text != "":
        texts.append(plt.text((winnin_position[0]+np.random.rand()*.9)%map_dim, (winnin_position[1]+np.random.rand()*.9)%map_dim, text, color=c))

print_number_of_documents_in_category()

plt.legend(handles=legend_elements, loc='upper left',prop={'size': 15})
# plt.xticks(range(map_dim))
# plt.yticks(range(map_dim))
# plt.grid()
plt.xlim([0, map_dim])
plt.ylim([0, map_dim])
plt.plot()
# Out:
# prawo cywilne: 237
# prawo administracyjne: 81
# prawo farmaceutyczne: 101
# prawo pracy: 151
# prawo medyczne: 377
# prawo międzynarodowe: 3
# prawo podatkowe: 34
# prawo konstytucyjne: 2
# prawo karne: 78
# inne: 0
# []

# %% [markdown]
# Digraph

# %%
from graphviz import Digraph

def get_category_indexes(vector):
    index = 0
    value = 0
    result = []
    for i, v in enumerate(vector):
        if v > value:
            value = v
            index = i
    for i, v in enumerate(vector):
        if v == value:
            result.append(i)
    return result

graph = Digraph('IUI')
categories = ['prawo cywilne','prawo administracyjne','prawo farmaceutyczne','prawo pracy','prawo medyczne','prawo międzynarodowe','prawo podatkowe','prawo konstytucyjne','prawo karne']
nodes = []
graph.format = 'svg'
# Add basic nodes for legal affairs
for i, category in enumerate(categories):
    letter = chr(ord('@')+(i+1))
    graph.node(letter, category)

# Add words from vectors
for i, vec in enumerate(vectors):
    nodeId = "{}".format(i)
    text = nodeId
    text = bestWords[i]
    categoryIndexes = get_category_indexes(vec)
    if len(categoryIndexes) == 0 or text == nodeId:
        continue
    graph.node(nodeId,text)
    for index in categoryIndexes:
        graph.edge(chr(ord('@')+(index+1)),nodeId)

resultGraph = graph.unflatten(stagger=70)

resultGraph

graph.render(directory='output').replace('\\','/')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File c:\IUI - Studia\IUI_Project\.venv\lib\site-packages\graphviz\backend\execute.py:81, in run_check(cmd, input_lines, encoding, quiet, **kwargs)
#      80     else:
# ---> 81         proc = subprocess.run(cmd, **kwargs)
#      82 except OSError as e:
#
# File ~\AppData\Local\Programs\Python\Python39\lib\subprocess.py:505, in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     503     kwargs['stderr'] = PIPE
# --> 505 with Popen(*popenargs, **kwargs) as process:
#     506     try:
#
# File ~\AppData\Local\Programs\Python\Python39\lib\subprocess.py:951, in Popen.__init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, user, group, extra_groups, encoding, errors, text, umask)
#     948             self.stderr = io.TextIOWrapper(self.stderr,
#     949                     encoding=encoding, errors=errors)
# --> 951     self._execute_child(args, executable, preexec_fn, close_fds,
#     952                         pass_fds, cwd, env,
#     953                         startupinfo, creationflags, shell,
#     954                         p2cread, p2cwrite,
#     955                         c2pread, c2pwrite,
#     956                         errread, errwrite,
#     957                         restore_signals,
#     958                         gid, gids, uid, umask,
#     959                         start_new_session)
#     960 except:
#     961     # Cleanup if the child failed starting.
#
# File ~\AppData\Local\Programs\Python\Python39\lib\subprocess.py:1420, in Popen._execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, unused_restore_signals, unused_gid, unused_gids, unused_uid, unused_umask, unused_start_new_session)
#    1419 try:
# -> 1420     hp, ht, pid, tid = _winapi.CreateProcess(executable, args,
#    1421                              # no special security
#    1422                              None, None,
#    1423                              int(not close_fds),
#    1424                              creationflags,
#    1425                              env,
#    1426                              cwd,
#    1427                              startupinfo)
#    1428 finally:
#    1429     # Child is launched. Close the parent's copy of those pipe
#    1430     # handles that only the child should have open.  You need
#    (...)
#    1433     # pipe will not close when the child process exits and the
#    1434     # ReadFile will hang.
#
# File c:\IUI - Studia\IUI_Project\.venv\lib\site-packages\debugpy\_vendored\pydevd\_pydev_bundle\pydev_monkey.py:901, in create_CreateProcess.<locals>.new_CreateProcess(app_name, cmd_line, *args)
#     899     send_process_created_message()
# --> 901 return getattr(_subprocess, original_name)(app_name, cmd_line, *args)
#
# FileNotFoundError: [WinError 2] Nie można odnaleźć określonego pliku
#
# The above exception was the direct cause of the following exception:
#
# ExecutableNotFound                        Traceback (most recent call last)
# Cell In[76], line 37
#      34     for index in categoryIndexes:
#      35         graph.edge(chr(ord('@')+(index+1)),nodeId)
# ---> 37 resultGraph = graph.unflatten(stagger=70)
#      39 resultGraph
#      41 graph.render(directory='output').replace('\\','/')
#
# File c:\IUI - Studia\IUI_Project\.venv\lib\site-packages\graphviz\_tools.py:171, in deprecate_positional_args.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     162     wanted = ', '.join(f'{name}={value!r}'
#     163                        for name, value in deprecated.items())
#     164     warnings.warn(f'The signature of {func.__name__} will be reduced'
#     165                   f' to {supported_number} positional args'
#     166                   f' {list(supported)}: pass {wanted}'
#     167                   ' as keyword arg(s)',
#     168                   stacklevel=stacklevel,
#     169                   category=category)
# --> 171 return func(*args, **kwargs)
#
# File c:\IUI - Studia\IUI_Project\.venv\lib\site-packages\graphviz\unflattening.py:50, in Unflatten.unflatten(self, stagger, fanout, chain)
#      22 """Return a new :class:`.Source` instance with the source
#      23     piped through the Graphviz *unflatten* preprocessor.
#      24
#    (...)
#      46     https://www.graphviz.org/pdf/unflatten.1.pdf
#      47 """
#      48 from . import sources
# ---> 50 out = self._unflatten(self.source,
#      51                       stagger=stagger, fanout=fanout, chain=chain,
#      52                       encoding=self.encoding)
#      54 kwargs = self._copy_kwargs()
#      55 return sources.Source(out,
#      56                       filename=kwargs.get('filename'),
#      57                       directory=kwargs.get('directory'),
#    (...)
#      62                       formatter=kwargs.get('formatter'),
#      63                       loaded_from_path=None)
#
# File c:\IUI - Studia\IUI_Project\.venv\lib\site-packages\graphviz\_tools.py:171, in deprecate_positional_args.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     162     wanted = ', '.join(f'{name}={value!r}'
#     163                        for name, value in deprecated.items())
#     164     warnings.warn(f'The signature of {func.__name__} will be reduced'
#     165                   f' to {supported_number} positional args'
#     166                   f' {list(supported)}: pass {wanted}'
#     167                   ' as keyword arg(s)',
#     168                   stacklevel=stacklevel,
#     169                   category=category)
# --> 171 return func(*args, **kwargs)
#
# File c:\IUI - Studia\IUI_Project\.venv\lib\site-packages\graphviz\backend\unflattening.py:61, in unflatten(source, stagger, fanout, chain, encoding)
#      58 if chain is not None:
#      59     cmd += ['-c', str(chain)]
# ---> 61 proc = execute.run_check(cmd, input=source, encoding=encoding,
#      62                          capture_output=True)
#      63 return proc.stdout
#
# File c:\IUI - Studia\IUI_Project\.venv\lib\site-packages\graphviz\backend\execute.py:84, in run_check(cmd, input_lines, encoding, quiet, **kwargs)
#      82 except OSError as e:
#      83     if e.errno == errno.ENOENT:
# ---> 84         raise ExecutableNotFound(cmd) from e
#      85     raise
#      87 if not quiet and proc.stderr:
#
# ExecutableNotFound: failed to execute WindowsPath('unflatten'), make sure the Graphviz executables are on your systems' PATH

# %% [markdown]
# NETWORK GRAPH

# %%
def get_category_indexes(vector):
    index = 0
    value = 0
    result = []
    for i, v in enumerate(vector):
        if v > value:
            value = v
            index = i
    for i, v in enumerate(vector):
        if v == value:
            result.append(i)
    return result

# %%
import plotly.graph_objects as go

import networkx as nx


G = nx.Graph()

categories = ['prawo cywilne','prawo administracyjne','prawo farmaceutyczne','prawo pracy','prawo medyczne','prawo międzynarodowe','prawo podatkowe','prawo konstytucyjne','prawo karne']
categories_positions = [[15.5,10],[2,16],[17.5,15],[5,7.5],[10,9],[3,10],[1.5,7.5],[2,10.5],[13,18]]
# Add basic nodes for legal affairs
for i, category in enumerate(categories):
    G.add_node(category)

# Add words from vectors
for i, vec in enumerate(vectors):
    categoryIndexes = get_category_indexes(vec)
    if len(categoryIndexes) == 0:
        continue
    w = bestWords[i]
    if len(w) == 1:
        continue
    G.add_node(w)
    for index in categoryIndexes:
        G.add_edge(categories[index],w)

nodes_to_remove = []
for n in G.nodes:
    if type(n) is int:
        nodes_to_remove.append(n)
        continue
    if n not in categories:
        indexOfWord = [x for x in range(len(bestWords)) if bestWords[x] == n][0]
        winner =  som.winner(vectors[indexOfWord])
        G.nodes[n]['pos'] = (winner[0]+np.random.rand()*.9,winner[1]+np.random.rand()*.9)
    else:
        ind = [x for x in range(len(categories)) if categories[x] == n][0]
        G.nodes[n]['pos'] = categories_positions[ind]

for ntr in nodes_to_remove:
    G.remove_node(ntr)

fig = go.Figure(
            layout=go.Layout(
            title='Words segregated by legal affairs + connections between them',
            titlefont=dict(size=16),
            showlegend=False,
            hovermode='closest',
            hoverlabel=dict(
                namelength=-1,
                font=dict(size=10),
            ),
            margin=dict(b=21, l=5, r=5, t=40),
            annotations=[dict(
                text="",
                showarrow=False,
                xref="paper", yref="paper")],
            xaxis=dict(showgrid=False, zeroline=False,showticklabels=False, mirror=True),
            yaxis=dict(showgrid=False, zeroline=False,
showticklabels=False, mirror=True)))

for edge in G.edges():
    x0, y0 = G.nodes[edge[0]]['pos']
    x1, y1 = G.nodes[edge[1]]['pos']
    fig.add_trace(go.Scatter(
    x=tuple([x0, x1, None]),
    y=tuple([y0, y1, None]),
    line=dict(width=1, color='darkgrey'),
    mode='lines'))


for g_index, node in enumerate(G.nodes()):
    x, y = G.nodes[node]['pos']
    color = 'silver'
    border_color = 'black'
    border_width = 2
    size = 40
    text = ''
    name = node
    if g_index > 8:
        word_index = [x for x in range(len(bestWords)) if bestWords[x] == node][0]
        vector = vectors[word_index]
        ind = get_category_index(vector)
        color = colors[ind]
        size = 10
        border_color = 0
        indexes = get_category_indexes(vector)
        cats = [categories[k] for k in indexes]
        name = '{} | {}\n'.format(name,cats)
    else:
        color = colors[g_index]
        text = str(node).split(' ')[1]

    fig.add_trace(go.Scatter(
    x=[x],
    y=[y],
    text=text,
    name=name,
    mode='markers+text',
    hoverinfo='name',
    marker=dict(
        showscale=True,
        reversescale=True,
        color=color,
        size=size,
        colorbar=dict(
            thickness=1,
            title='Node Connections',
            xanchor='left',
            titleside='right'
        ),
        line=dict(
            color=border_color,
            width = border_width
        ))))

fig.show()

# %%
ambiguouslyAssignedDocuments = OrderedDict()
documentIndex = 0
for i, vec in enumerate(vectors):
    documentInfo = OrderedDict()
    categoryIndexes = get_category_indexes(vec)
    if len(categoryIndexes) < 2:
        continue
    documentInfo['Liczba kategorii prawnych'] = len(categoryIndexes)
    documentInfo['Przypisane kategorie prawne'] = [categories[k] for k in categoryIndexes]
    documentInfo['Tekst'] = allSentences[i]
    documentInfo['Wektor słów'] = allWords[i]
    
    ambiguouslyAssignedDocuments[documentIndex] = documentInfo
    documentIndex += 1

dataFrame = pd.DataFrame(ambiguouslyAssignedDocuments)
dataFrame = dataFrame.T
dataFrame = dataFrame.sort_values(by='Liczba kategorii prawnych',ascending=False)
print(len(vectors))
# Out:
# 1064

# %%
dataFrame.to_markdown('data/all_sentences.md')

# %%
# !pip install openpyxl
# Out:
# Collecting openpyxl
#   Using cached openpyxl-3.1.2-py2.py3-none-any.whl (249 kB)
# Collecting et-xmlfile (from openpyxl)
#   Using cached et_xmlfile-1.1.0-py3-none-any.whl (4.7 kB)
# Installing collected packages: et-xmlfile, openpyxl
# Successfully installed et-xmlfile-1.1.0 openpyxl-3.1.2

# %%
dataFrame.to_excel(r'data/all_sentences.xlsx', index=False)

# %%
dataFrame
# Out:
#    Liczba kategorii prawnych  \
# 57                         5
# 2                          4
# 12                         4
# 60                         3
# 75                         3
# ..                       ...
# 29                         2
# 28                         2
# 27                         2
# 26                         2
# 82                         2
#
#                           Przypisane kategorie prawne  \
# 57  [prawo cywilne, prawo administracyjne, prawo p...
# 2   [prawo cywilne, prawo administracyjne, prawo f...
# 12  [prawo cywilne, prawo administracyjne, prawo p...
# 60  [prawo farmaceutyczne, prawo medyczne, prawo p...
# 75  [prawo cywilne, prawo administracyjne, prawo m...
# ..                                                ...
# 29               [prawo administracyjne, prawo pracy]
# 28             [prawo farmaceutyczne, prawo medyczne]
# 27                      [prawo medyczne, prawo karne]
# 26             [prawo farmaceutyczne, prawo medyczne]
# 82                   [prawo cywilne, prawo podatkowe]
#
#                                                 Tekst  \
# 57  czy w przypadku w którym księgowy nie dotrzyma...
# 2   czy spółdzielnia mieszkaniowa może wybudować w...
# 12  czy mając na uwadze przepisy rozporządzenia pa...
# 60  jakie będą zasady wystawiania recept papierowy...
# 75  czy domek mobilny zbudowany na zarejestrowanej...
# ..                                                ...
# 29  czy jeden z dwóch wspólników i członków zarząd...
# 28  czy na erecepcie z efferalgan codeine musi być...
# 27  czy pacjentka może domagać się wypłaty odszkod...
# 26  czy prawdą jest że od  stycznia  r obowiązują ...
# 82  czy w przypadku rozwodu klientce przysługują r...
#
#                                        Wektor słów
# 57  [dotrzyma, wezwać, wejść, biura, przekazanych]
# 2             [wybudować, wiatę, granicy, granicy]
# 12    [parlamentu, rady, przetwarzaniem, ochronie]
# 60                         [papierowych, lipca, r]
# 75                [zbudowany, ciężarowej, działce]
# ..                                             ...
# 29                            [swobodnego, wglądu]
# 28                               [być, substancji]
# 27                      [wypłaty, ubezpieczyciela]
# 26                                 [stycznia, pro]
# 82                            [rozwodu, budynkiem]
#
# [83 rows x 4 columns]
